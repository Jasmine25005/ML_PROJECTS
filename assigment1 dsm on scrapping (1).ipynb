# %%
#!pip install BeautifulSoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: BeautifulSoup4 in c:\users\jasmi\appdata\roaming\python\python312\site-packages (4.13.0b2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jasmi\appdata\roaming\python\python312\site-packages (from BeautifulSoup4) (2.6)
# Requirement already satisfied: typing-extensions in c:\users\jasmi\appdata\roaming\python\python312\site-packages (from BeautifulSoup4) (4.12.2)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in c:\users\jasmi\appdata\roaming\python\python312\site-packages (3.0.1)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from urllib.request import urlopen  # To open a URL
from bs4 import BeautifulSoup  # For parsing the HTML content

# %%
# Step 1: Open the URL and read the HTML content
myurl = urlopen("https://www.artpal.com/buy/abstract/").read()
print(myurl)
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n\t<meta charset="UTF-8" />\r\n\t<title>Buy Abstract at ArtPal</title>\r\n    <link rel="preload" as="image" href="/img/lmore.png?1">\r\n\r\n    <link rel="preload" as="image" href="/img/img.png?21">\r\n\t<link rel="preload" as="image" href="https://x.artpal.com/img/c.gif">\r\n\t<meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1" />\r\n\t<!-- Google tag (gtag.js) -->\r\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=G-ZGEZCKRVQE"></script>\r\n\t<script>\r\n\t  window.dataLayer = window.dataLayer || [];\r\n\t  function gtag(){dataLayer.push(arguments);}\r\n\t  gtag(\'js\', new Date());\r\n\t  gtag(\'config\', \'G-ZGEZCKRVQE\');\r\n\t  \r\n\t</script>\r\n\t<script defer src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.1/jquery.min.js"></script>\r\n\t<script defer src="https://x.artpal.com/js/ex.js?10"></script>\r\n\t<script defer src="https://x.artpal.com/js/main.js?112"></script>\r\n\t<link rel="stylesheet" href="https://x.artpal.com/css/main.css?116" type="text/css" />\r\n\t<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" />\r\n\t<link rel="apple-touch-icon" href="/apple-touch-icon.png" />\r\n\t<link rel="canonical" href="https://www.ArtPal.com/buy/abstract/" />\r\n\t<meta property="og:url" content="https://www.ArtPal.com/buy/abstract/" />\r\n\t<meta property="og:title" content="Buy Abstract at ArtPal" />\r\n\t<meta property="og:type" content="website" />\r\n\t<meta property="og:image" content="https://img.artpal.com/544392/61-23-11-9-11-47-32m.jpg" />\r\n\t<meta property="og:ttl" content="2419200" />\r\n\t<meta property="og:site_name" content="ArtPal" />\r\n\t<meta property="fb:app_id" content="705660522887211" />\r\n\t<meta property="fb:admins" content="1247318330" />\r\n\t<meta property="og:description" content="Buy Abstract art, including Collage, Color, Figurative, Fractal, Geometric, Irregular Forms, Landscape, Man-made Objects, Movement, Organic, Text, and Other Abstract." />\r\n\t<meta name="description" content="Buy Abstract art, including Collage, Color, Figurative, Fractal, Geometric, Irregular Forms, Landscape, Man-made Objects, Movement, Organic, Text, and Other Abstract." />\r\n<!--[if gte IE 5.5]>\r\n<![if lte IE 7]>\r\n<style type="text/css">\r\nbody{overflow-y:auto;}\r\n</style>\r\n<![endif]>\r\n<![endif]-->\r\n\r\n</head>\r\n<body>\r\n\t<form method="post" action="/buy/abstract/" id="aspnetForm">\r\n<input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="KSYdaERv4LU+Hz4nbLmaIyBlRM4GZYKy92sG05/B1J49K8/fG3UPtPAYMsZ8B9tkYsuQUO+owkl/LlGoE+8Em6JuK0SzI54z3WI393Z5l+FEqAE85LM3cwz9PnIMJ33jUI0pyZMIYmHl3f9z9voSoGUqo9RI4Jink0gcB4vAP0InJ8qLJL5TjVVTHZ6D9utnZwB2rg==" />\r\n\r\n\r\n<script src="/ScriptResource.axd?d=rNe2jKH6rSKLQY77K3RWdTl_5TvT-UzUdQBrUG3z3ecBz3VKUDCnUfCbR5TOeorARqSV7sDewmvSImjFQNo94hsnNT663zlsMESA_f5b0PwdAyxomT2D6KNVx1lV-gS64eagga3thDxROOfXdthDfS0X1TqnfzhL4cnYA2u_na5Z9BicYUDAFDXDzd8mSdiqjgzt9CHwAzfs7GTNd_jru-nb6svAiPgrOzQ5NWYBn3ia-h8jzB0ATjRILrA-Kj-2TTFyWC-g2DHxPDnyRDHhQv9Rp-I1" type="text/javascript"></script>\r\n<input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="765B2646" />\r\n\t\r\n\t<div id="popupWrapper">\r\n\t<span id="ItemUpdatePanel">\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="EditItemPopupUpdatePanel">\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="ShoppingBagUpdatePanel">\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="ReviewImgUpdatePanel">\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="LoginUpdatePanel">\r\n\t\t\t\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="MsgUpdatePanel">\r\n\t\t\t\r\n\t\t\t\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="OtherUP">\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="Other2UP">\r\n\t\t\t\r\n\t\t</span>\r\n\t<span id="Other3UP">\r\n\t\t\t\r\n\t\t</span>\r\n\t<div class="sBoxFx"><style type="text/css">\r\n@media print {\r\n#mainWrapper { display: none; }\r\n}\r\n</style>\r\n<input type="hidden" name="zIndex" value="18" />\r ...

# %%
# Step 2: Parse the HTML content using BeautifulSoup, specifying the parser
thehtmlcode = BeautifulSoup(myurl, features="html.parser")
#Print the parsed HTML content
print(thehtmlcode)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Buy Abstract at ArtPal</title>
# <link as="image" href="/img/lmore.png?1" rel="preload"/>
# <link as="image" href="/img/img.png?21" rel="preload"/>
# <link as="image" href="https://x.artpal.com/img/c.gif" rel="preload"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-ZGEZCKRVQE"></script>
# <script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
# 	  gtag('config', 'G-ZGEZCKRVQE');
#
# 	</script>
# <script defer="" src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.1/jquery.min.js"></script>
# <script defer="" src="https://x.artpal.com/js/ex.js?10"></script>
# <script defer="" src="https://x.artpal.com/js/main.js?112"></script>
# <link href="https://x.artpal.com/css/main.css?116" rel="stylesheet" type="text/css">
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="/apple-touch-icon.png" rel="apple-touch-icon">
# <link href="https://www.ArtPal.com/buy/abstract/" rel="canonical"/>
# <meta content="https://www.ArtPal.com/buy/abstract/" property="og:url"/>
# <meta content="Buy Abstract at ArtPal" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://img.artpal.com/544392/61-23-11-9-11-47-32m.jpg" property="og:image"/>
# <meta content="2419200" property="og:ttl"/>
# <meta content="ArtPal" property="og:site_name"/>
# <meta content="705660522887211" property="fb:app_id"/>
# <meta content="1247318330" property="fb:admins"/>
# <meta content="Buy Abstract art, including Collage, Color, Figurative, Fractal, Geometric, Irregular Forms, Landscape, Man-made Objects, Movement, Organic, Text, and Other Abstract." property="og:description"/>
# <meta content="Buy Abstract art, including Collage, Color, Figurative, Fractal, Geometric, Irregular Forms, Landscape, Man-made Objects, Movement, Organic, Text, and Other Abstract." name="description"/>
# <!--[if gte IE 5.5]>
# <![if lte IE 7]>
# <style type="text/css">
# body{overflow-y:auto;}
# </style>
# <![endif]>
# <![endif]-->
# </link></link></link></head>
# <body>
# <form action="/buy/abstract/" id="aspnetForm" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="KSYdaERv4LU+Hz4nbLmaIyBlRM4GZYKy92sG05/B1J49K8/fG3UPtPAYMsZ8B9tkYsuQUO+owkl/LlGoE+8Em6JuK0SzI54z3WI393Z5l+FEqAE85LM3cwz9PnIMJ33jUI0pyZMIYmHl3f9z9voSoGUqo9RI4Jink0gcB4vAP0InJ8qLJL5TjVVTHZ6D9utnZwB2rg=="/>
# <script src="/ScriptResource.axd?d=rNe2jKH6rSKLQY77K3RWdTl_5TvT-UzUdQBrUG3z3ecBz3VKUDCnUfCbR5TOeorARqSV7sDewmvSImjFQNo94hsnNT663zlsMESA_f5b0PwdAyxomT2D6KNVx1lV-gS64eagga3thDxROOfXdthDfS0X1TqnfzhL4cnYA2u_na5Z9BicYUDAFDXDzd8mSdiqjgzt9CHwAzfs7GTNd_jru-nb6svAiPgrOzQ5NWYBn3ia-h8jzB0ATjRILrA-Kj-2TTFyWC-g2DHxPDnyRDHhQv9Rp-I1" type="text/javascript"></script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="765B2646"/>
# <div id="popupWrapper">
# <span id="ItemUpdatePanel">
# </span>
# <span id="EditItemPopupUpdatePanel">
# </span>
# <span id="ShoppingBagUpdatePanel">
# </span>
# <span id="ReviewImgUpdatePanel">
# </span>
# <span id="LoginUpdatePanel">
# </span>
# <span id="MsgUpdatePanel">
# </span>
# <span id="OtherUP">
# </span>
# <span id="Other2UP">
# </span>
# <span id="Other3UP">
# </span>
# <div class="sBoxFx"><style type="text/css">
# @media print {
# #mainWrapper { display: none; }
# }
# </style>
# <input name="zIndex" type="hidden" value="18"/>
# <div class="PopupBgTint"><div class="close"></div></div><div class="sBox"><input autocomplete="off" class="s" maxlength="50" name="s!1" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Search Art" size="38" type="text" value=""/><input id="SubmitS" name="Search:" onclick="offPh();srch(1);return rF();" type="submit" value=""/><span class="sBut"></span>
# <div class="sFltr">
# <div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!1" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!1" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(0); return rF();" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/">Reset</a></div>
# </div>
# </div>
# </div>
# </div>
# <div id="mainWrapper">
# <div class="hdr">
# <div class="wrapper">
# <div class="mmA"><a href="/"><img alt="ArtPal | Buy Art &amp; Sell Artwork Online - Paintings Prints Photography" height="29" src="https://x.artpal.com/img/artpal.png" width="110"/></a></div>
# <h1><a href="/buy/">Buy<span> Art</span></a></h1><h3><a href="/sellart/">Sell<span> Art</span></a></h3><h3><a href="/orders.aspx"><span>My </span>Orders</a></h3>
# <div class="mmB"><div id="MenuUpdatePanel">
# <a id="mmSm" onclick="lm(this,'lm');return rF();"><span></span></a><a class="cart" href="/index.aspx?sb=1" onclick="go('SB:');return rF();"><span class="ico"></span><span class="txt">Cart</span><span class="cnt">0</span></a><div id="mmBL"><a href="/" onclick="go('ShowLogin:');return rF();">Login</a></div><div class="lm" id="lm"><a class="mmSm" href="/buy/">Buy Art</a><a class="mmSm" href="/sellart/">Sell Art</a><a class="mmSm" href="/orders.aspx">My Orders</a><a class="mmSm" href="/" onclick="go('ShowLogin:');return rF();">Login</a></div>
# </div></div>
# </div>
# </div>
# <div class="sBoxW"><div class="sBox"><input autocomplete="off" class="s" maxlength="50" name="s" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Search Art" size="38" type="text" value=""/><input id="SubmitS" name="Search:" onclick="offPh();srch(1);return rF();" type="submit" value=""/><span class="sBut"></span>
# <div class="sFltr">
# <div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o" tabindex="-1" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o" tabindex="-1" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(1); return rF();" tabindex="-1" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/" tabindex="-1">Reset</a></div>
# </div>
# </div></div>
# <div class="wrapper">
# <div class="items"><div class="iCgu"></div>
# <div class="iC iBox"><div class="iBoxCent"><div class="i2Box"><div class="navBox"><span class="fTtl">Subjects</span><div class="navB"><a href="/"><span class="arwB"></span>Home</a><h1><a href="/buy/abstract/"><span class="arwB"></span>Abstract</a></h1></div><div class="boxCtnt indent"><a href="/buy/abstract/collage/">Collage</a><a href="/buy/abstract/color/">Color</a><a href="/buy/abstract/figurative/">Figurative</a><a href="/buy/abstract/fractal/">Fractal</a><a href="/buy/abstract/geometric/">Geometric</a><a href="/buy/abstract/irregular-forms/">Irregular Forms</a><a href="/buy/abstract/landscape/">Landscape</a><a href="/buy/abstract/man-made-objects/">Man-made Objects</a><a href="/buy/abstract/movement/">Movement</a><a href="/buy/abstract/organic/">Organic</a><a href="/buy/abstract/text/">Text</a><a href="/buy/abstract/other-abstract/">Other Abstract</a></div></div></div>
# <div class="fBox" id="fBox"><div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><br/><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!2" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!2" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div><br/>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><br/><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div><br/>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(0); return rF();" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/">Reset</a></div></div></div><br/><div class="i2Box subA" id="sub"><span class="fanc">Welcome, art lover!</span><br/><div class="subB"><strong>Be the first to receive coupons and sales.</strong><br/><div class="subC"><div><input autocomplete="email" maxlength="64" name="subEmail" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Your Email" size="22" type="text"/></div><div><span class="err" id="subEmailErr"></span></div><input class="button3 minpad" id="SubmitSub" onclick="offPh();go('Sub:',this,'s5w');return rF();" type="submit" value="Subscribe"/><div class="small">Your email is kept private and is not shared. You can unsubscribe at any time.</div></div><div class="subD margTop20"></div></div></div></div><div class="iC iCfnd"><div class="fnd"><span style="">Found <span>316184</span> matches</span><br/><div class="fltrPad"><div class="fltr" title="Abstract"><a class="fltrRem" href="/?"></a><span></span><div>Abstract</div></div></div></div></div><a class="iC" href="?i=293445-61" onclick="go('I:293445-61',this);return rF();"><div class="iI" style="padding-bottom:100%;"><img alt="Just Triangles - Bob Rupp" src="https://img.artpal.com/544392/61-47-32t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Just Triangles</strong><em>Bob Rupp</em></div></div></a><a class="iC" href="?i=293445-203" onclick="go('I:293445-203',this);return rF();"><div class="iI" style="padding-bottom:66.6667%;"><img alt="Stained Glass Sailboat - Bob Rupp" src="https://img.artpal.com/544392/203-13-25t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Stained Glass Sailboat</strong><em>Bob Rupp</em></div></div></a><a class="iC" href="?i=4610-15" onclick="go('I:4610-15',this);return rF();"><div class="iI" style="padding-bottom:100%;width:65.666666666666666666666666670%"><img alt="Redbud Abstract - Cara's Garden" src="https://img.artpal.com/0164/15-10-35t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Redbud Abstract</strong><em>Cara's Garden</em></div></div></a><a class="iC" href="?i=22-1403" onclick="go('I:22-1403',this);return rF();"><div class="iI" style="padding-bottom:100%;width:79.00%"><img alt="Rose Amonst the Trees - Paintings by John Lautermilch" src="https://img.artpal.com/22/1403-47-49t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Rose Amonst the Trees</strong><em>Paintings by John Lautermilch</em></div></div></a><a class="iC" href="?i=228274-96" onclick="go('I:228274-96',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Modern Circus Town Pattern - Tina Mitchell Art" src="https://img.artpal.com/472822/96-43-32t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Modern Circus Town Pattern</strong><em>Tina Mitchell Art</em></div></div></a><a class="iC" href="?i=228274-66" onclick="go('I:228274-66',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Modern Circus Town Pop Art - Tina Mitchell Art" src="https://img.artpal.com/472822/66-42-15t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Modern Circus Town Pop Art</strong><em>Tina Mitchell Art</em></div></div></a><a class="iC" href="?i=22-1083" onclick="go('I:22-1083',this);return rF();"><div class="iI" style="padding-bottom:100%;"><img alt="End of a Small Planet - Paintings by John Lautermilch" src="https://img.artpal.com/22/1083-34-34t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>End of a Small Planet</strong><em>Paintings by John Lautermilch</em></div></div></a><a class="iC" href="?i=228274-55" onclick="go('I:228274-55',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Retro Circus Ticket Pattern - Tina Mitchell Art" src="https://img.artpal.com/472822/55-40-28t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><s ...
# <p>ArtPal's art collection gives you access to an eclectic mix of artworks &amp; artists from around the world, including figurative art, abstract art, contemporary masterpieces, impressionist art, art from the masters, realism art, abstract expressionism, modern art, and much more. The subjects depicted span the spectrum, from landscapes to animals to people to flowers to food &amp; beverage art, everyday life art, historical art, holiday art, classical art, political &amp; religious art, fantasy art, humor, abstracts, sports art, childrens art, and many more art subjects. These captivating artworks hail from galleries &amp; artists all over the globe, offering a rich tapestry of styles, subjects, and artistic types.</p>
# <p>At ArtPal, we feature a diverse selection of artists and art galleries, so you can find your unique style throughout the online store. The offerings encompass a wide range of art forms, such as fine art prints, original art, canvas prints, abstract paintings, oil paintings, giclées, limited editions, photography, drawings &amp; illustrations, digital art &amp; AI art, mixed media art, metal art, and more. Whether you're enhancing your home, or business, or professional workspace, you'll finally find the wall art that you've been searching for.</p>
# <p>In addition, it's easy to frame &amp; mat most any artwork you find on ArtPal, using the powerful online frameshop. Featuring high-quality frames &amp; mats with unparalleled custom framing workmanship and attention to detail, you're sure to be thrilled with your new art.</p>
# <p>Whether you're an experienced art collector or embarking on your first art purchase, ArtPal has an expansive art collection to ensure you find the art that's just perfect for you.</p>
# <p>Let's go art shopping!</p></div><br/><div class="wrapper footSub" id="subF"><div class="footSubB">
# <div class="subC"><strong>Get ArtPal coupons in your inbox.</strong> <div><div><input autocomplete="email" maxlength="64" name="subFEmail" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Your Email" size="25" style="" type="text"/><br/><span class="err" id="subFEmailErr"></span></div> <input class="button3" id="SubmitSubF" onclick="offPh();go('Sub:F',this,'s5w');return rF();" type="submit" value="Subscribe"/></div><br/><div class="small">Your email is kept private and is not shared. You can unsubscribe at any time.</div></div><div class="subD"></div></div></div><div class="clearfix"></div>
# </div>
# <div class="footer"><div class="wrapper"><div class="footB"><img alt="ArtPal" height="29" src="https://x.artpal.com/img/artpal2.png" width="110"/></div><div class="footA small"><div class="m2 pad"><a href="#" onclick="m(this,'mShareF',1);return rF();">SHARE ARTPAL<span class="arw"></span></a><div class="m share share32" id="mShareF"><div data-img="https://x.artpal.com/img/artpal_share.png" data-title="Buy Art &amp; Sell Art! Paintings Prints Photography | ArtPal" data-url="https://www.ArtPal.com"><a class="FB" href="#" onclick="share(this);return rF();" title="Facebook"></a><a class="T" href="#" onclick="share(this);return rF();" title="Twitter"></a><a class="P" href="#" onclick="share(this);return rF();" title="Pinterest"></a><a class="E" href="#" onclick="share(this);return rF();" title="Email"></a><a class="L" href="#" onclick="share(this);return rF();" title="Copy Link"></a><a class="More" href="#" onclick="share(this);event.stopPropagation();return rF();" title="More...">More...</a></div><div class="clearfix"></div><div class="txt">Share ArtPal &amp; earn 5% referral bonuses. <a href="/refer/" target="_blank">Learn more</a></div></div></div><a href="/terms.aspx">TERMS</a><a href="/privacy.aspx">PRIVACY</a><a href="/contact.aspx" onclick="go('Contact:');return rF();">CONTACT</a><em>© 2025 ARTPAL</em></div></div></div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# window.addEventListener('load', function () { dfltTtl='Buy Abstract at ArtPal';
# upTtl("Buy Abstract at ArtPal", 0);
# $('#__EVENTTARGET').val('');$('#__EVENTARGUMENT').val('');
# $.cookie('tzo',-(new Date().getTimezoneOffset()),{expires:365, path:'/; SameSite=None; Secure'});
# initPh();
# $('#lMore').on('click',function(){loadMore=1;$(this).find('.loadSpin').spin('sm');appendItems([],1);return rF();});
# var iArry=[[342732,10,"36-45","Art Is For Everyone","Gallery 26N 80W",0,.6667],[221142,21,"42-34","Abstract River 2025 08270425","Cindy\u0026#39;s Creative Corner",0,1],[12941,50,"11-58","Yumata wife of Valu","Unispirical Muse",0,.6333],[304649,32,"42-38","on top of the world","Donnette Levine Bufton",0,.91],[539,93,"9-27","Cold Weather","Nic Squirrell",0,1],[22,550,"33-59","Abstract 1-2005","Paintings by John Lautermilch",0,.7833],[327455,38,"35-35","forest of the elders magic of wizard","Atrisane",0,.9667],[327455,32,"0-28","apple of the eye","Atrisane",0,.7967],[312387,16,"39-48","Interior paintings of Mallorca","Avanesova Elena AVA",0,1],[331939,12,"28-38","Image of the Unseen Self","Hummingbird - Where things shimmer and blur",0,.6667],[327455,7,"19-21","Geo butterfly","Atrisane",0,.78],[32227,13,"39-56","Divergent","Charlotte Blanchard",0,1],[2534,465,"25-44","Mountain High","David Zimmerman Fine Art",0,1.5152],[343457,4,"47-6","Gaelic","Monica Serban",0,1.0239],[215331,178,"31-24","In a moment","Ray",0,.64],[346550,11,"46-9","Drifting2","Margie Nottingham",0,1.0274],[22,183,"43-28","Abstract 10-2004","Paintings by John Lautermilch",0,.9867],[329030,438,"58-8","“Fragments of Light”","DRIFT POINT GALLERY",0,1.0169],[346550,10,"24-1","Drifting","Margie Nottingham",0,.98],[2534,67,"7-43","In The Mood","David Zimmerman Fine Art",0,1.3636],[2534,395,"18-57","Besert Bloom","David Zimmerman Fine Art",0,.8],[2534,404,"21-48","Leopard Skin Pill Box Hat","David Zimmerman Fine Art",0,1.25],[2534,488,"34-2","Stone age By Comparison","David Zimmerman Fine Art",0,1.4151],[346310,3,"49-22","“In the eye of becoming”","Jasmine Joyce",0,.7867],[346310,4,"58-12","“Rising”","Jasmine Joyce",0,.98],[329030,437,"32-36","“Radiance on the Horizon”","DRIFT POINT GALLERY",0,1.0169],[327674,49,"21-37","Blue roses","Amadesi Claudia",0,1.0101],[327674,69,"29-33","Totem urbano","Amadesi Claudia",0,1],[346085,112,"35-34","Elegant Abstract Leaves Wall Art","Nova Strokes",0,.6667],[12941,82,"12-55","Penxia son of Bacha","Unispirical Muse",0,.7733],[12941,84,"36-40","Subara wife of Bacha","Unispirical Muse",0,.7733],[346550,9,"54-45","Thresholds .","Margie Nottingham",0,.77],[331939,22,"10-23","Neither Zero nor One","Hummingbird - Where things shimmer and blur",0,.6667],[312387,87,"2-13","Abstract Painting Colors of Mallorca","Avanesova Elena AVA",0,1.5],[2534,293,"58-58","Madrigals","David Zimmerman Fine Art",0,1.0345],[346933,1,"11-53","Beholder","☆jjpsychcreep☆",0,.7933],[345733,5,"54-48","\u0026quot;Through the Flow\u0026quot;","Irina Beazley",0,.7233],[248349,11,"47-15","Revised Change of Heart","Diane Leon",0,.79],[2534,63,"20-17","Intensity","David Zimmerman Fine Art",0,1.3393],[346505,18,"58-41","THE FORGOTTEN SWING","XUXU",0,.7933],[312387,32,"10-49","Mallorca","Avanesova Elena AVA",0,1],[346550,8,"10-55","Yesterdays dreams","Margie Nottingham",0,1.2097],[215331,176,"10-56","Spectre","Ray",0,.6633],[22,891,"48-26","Palette Abstraction #13","Paintings by John Lautermilch",0,1.4925],[215331,174,"3-35","Ghostly","Ray",0,.6633],[215331,175,"3-39","Ocean wave.","Ray",0,1.1407],[5980,160,"30-39","Abstract Pattern in Red, Gold, Blue","JHughes Works of Art",0,1],[324961,24,"31-8","Andy Warhol Mick Jagger","Harmonia Gallery",0,1],[324961,44,"31-58","Andy Warhol Princess Diana","Harmonia Gallery",0,1],[324961,50,"43-48","Warhol Mao Tse Tung (Yellow)","Harmonia Gallery",0,1],[324961,82,"12-50","Warhol Brigitte Bardot (Green)","Harmonia Gallery",0,1],[324961,121,"56-58","Roy Lichtenstein Two Nudes","Harmonia Gallery",0,1],[324961,125,"21-59","Interior with mobile painting","Harmonia Gallery",0,1],[324961,126,"22-30","Andy Warhol Butterfly (Purple)","Harmonia Gallery",0,1],[324961,127,"22-53","Lichtenstein Nude in Kitchen","Harmonia Gallery",0,1],[324961,128,"17-18","Reflections on Crash Lichtenstein","Harmonia Gallery",0,1],[324961,129,"17-49","Lichtenstein Girl and Spray can","Harmonia Gallery",0,1],[324961,130,"18-20","Lichtenstein Reflections on Minerva", ...
# appendItems(iArry);
# initM(); initLz();
# initSChkbox(); srchFx();
# var lastItem={"gID":"346550","iID":"3"};
# var scrollID='index';scrollBotOn(scrollID,function(){$.getJSON('/getItems.ashx?',{cID:0.0100000000,gID:lastItem.gID,iID:lastItem.iID},function(data){if(data.iArry.length<100){scrollBotOff(scrollID);}lastItem=data.lastItem;appendItems(data.iArry,1);});});
#
# upTtl("Buy Abstract at ArtPal", 0);
#  });
# //]]>
# </script>
# </form>
# <div class="Popup" id="wait"><div class="PopupBgTint"></div><div class="PopupBg"><div class="waitA"><div class="waitB"></div><p><strong id="waitMsg"></strong></p></div></div></div>
# </body>
# </html>

# %%
# Step 3: Extract the content of the first anchor tag (<a>) found in the HTML
text =thehtmlcode.a.contents # 'contents' will get the content inside the <a> tag
print(text)
# Out:
# ['Reset']

# %%
# Step 4: Extract and display the title of the webpage
print("Title: ",thehtmlcode.title) # 'title' gets the content of the <title> tag
# Out:
# Title:  <title>Buy Abstract at ArtPal</title>

# %%
# Step 5: Display the entire body of the webpage
print("Body: ",thehtmlcode.body) # 'body' gets the content of the <body> tag

#This HTML snippet was identified by inspecting the structure of a web page and locating the div containing the "Table of Content". Extract the text of the 'table_of_content' div
Categories = thehtmlcode.find('div', id='popupWrapper') # Get the text from the extracted div, removing extra whitespace
if Categories:
    toc_text = Categories.get_text(strip= True , separator=' \n ')
    print("Categories:")
    print(toc_text)
else :
    print("No 'table_of_content' found.")

#Step 6: #to get all of the links mentioned in a page
for link in thehtmlcode.find_all('a'):
    href = link.get('href')
    if href:
        print(href)
# Out:
# Body:  <body>
# <form action="/buy/abstract/" id="aspnetForm" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="KSYdaERv4LU+Hz4nbLmaIyBlRM4GZYKy92sG05/B1J49K8/fG3UPtPAYMsZ8B9tkYsuQUO+owkl/LlGoE+8Em6JuK0SzI54z3WI393Z5l+FEqAE85LM3cwz9PnIMJ33jUI0pyZMIYmHl3f9z9voSoGUqo9RI4Jink0gcB4vAP0InJ8qLJL5TjVVTHZ6D9utnZwB2rg=="/>
# <script src="/ScriptResource.axd?d=rNe2jKH6rSKLQY77K3RWdTl_5TvT-UzUdQBrUG3z3ecBz3VKUDCnUfCbR5TOeorARqSV7sDewmvSImjFQNo94hsnNT663zlsMESA_f5b0PwdAyxomT2D6KNVx1lV-gS64eagga3thDxROOfXdthDfS0X1TqnfzhL4cnYA2u_na5Z9BicYUDAFDXDzd8mSdiqjgzt9CHwAzfs7GTNd_jru-nb6svAiPgrOzQ5NWYBn3ia-h8jzB0ATjRILrA-Kj-2TTFyWC-g2DHxPDnyRDHhQv9Rp-I1" type="text/javascript"></script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="765B2646"/>
# <div id="popupWrapper">
# <span id="ItemUpdatePanel">
# </span>
# <span id="EditItemPopupUpdatePanel">
# </span>
# <span id="ShoppingBagUpdatePanel">
# </span>
# <span id="ReviewImgUpdatePanel">
# </span>
# <span id="LoginUpdatePanel">
# </span>
# <span id="MsgUpdatePanel">
# </span>
# <span id="OtherUP">
# </span>
# <span id="Other2UP">
# </span>
# <span id="Other3UP">
# </span>
# <div class="sBoxFx"><style type="text/css">
# @media print {
# #mainWrapper { display: none; }
# }
# </style>
# <input name="zIndex" type="hidden" value="18"/>
# <div class="PopupBgTint"><div class="close"></div></div><div class="sBox"><input autocomplete="off" class="s" maxlength="50" name="s!1" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Search Art" size="38" type="text" value=""/><input id="SubmitS" name="Search:" onclick="offPh();srch(1);return rF();" type="submit" value=""/><span class="sBut"></span>
# <div class="sFltr">
# <div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!1" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!1" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!1" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!1" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p!1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!1" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(0); return rF();" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/">Reset</a></div>
# </div>
# </div>
# </div>
# </div>
# <div id="mainWrapper">
# <div class="hdr">
# <div class="wrapper">
# <div class="mmA"><a href="/"><img alt="ArtPal | Buy Art &amp; Sell Artwork Online - Paintings Prints Photography" height="29" src="https://x.artpal.com/img/artpal.png" width="110"/></a></div>
# <h1><a href="/buy/">Buy<span> Art</span></a></h1><h3><a href="/sellart/">Sell<span> Art</span></a></h3><h3><a href="/orders.aspx"><span>My </span>Orders</a></h3>
# <div class="mmB"><div id="MenuUpdatePanel">
# <a id="mmSm" onclick="lm(this,'lm');return rF();"><span></span></a><a class="cart" href="/index.aspx?sb=1" onclick="go('SB:');return rF();"><span class="ico"></span><span class="txt">Cart</span><span class="cnt">0</span></a><div id="mmBL"><a href="/" onclick="go('ShowLogin:');return rF();">Login</a></div><div class="lm" id="lm"><a class="mmSm" href="/buy/">Buy Art</a><a class="mmSm" href="/sellart/">Sell Art</a><a class="mmSm" href="/orders.aspx">My Orders</a><a class="mmSm" href="/" onclick="go('ShowLogin:');return rF();">Login</a></div>
# </div></div>
# </div>
# </div>
# <div class="sBoxW"><div class="sBox"><input autocomplete="off" class="s" maxlength="50" name="s" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Search Art" size="38" type="text" value=""/><input id="SubmitS" name="Search:" onclick="offPh();srch(1);return rF();" type="submit" value=""/><span class="sBut"></span>
# <div class="sFltr">
# <div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c" tabindex="-1" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o" tabindex="-1" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o" tabindex="-1" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz" tabindex="-1" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p" tabindex="-1" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p" tabindex="-1" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(1); return rF();" tabindex="-1" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/" tabindex="-1">Reset</a></div>
# </div>
# </div></div>
# <div class="wrapper">
# <div class="items"><div class="iCgu"></div>
# <div class="iC iBox"><div class="iBoxCent"><div class="i2Box"><div class="navBox"><span class="fTtl">Subjects</span><div class="navB"><a href="/"><span class="arwB"></span>Home</a><h1><a href="/buy/abstract/"><span class="arwB"></span>Abstract</a></h1></div><div class="boxCtnt indent"><a href="/buy/abstract/collage/">Collage</a><a href="/buy/abstract/color/">Color</a><a href="/buy/abstract/figurative/">Figurative</a><a href="/buy/abstract/fractal/">Fractal</a><a href="/buy/abstract/geometric/">Geometric</a><a href="/buy/abstract/irregular-forms/">Irregular Forms</a><a href="/buy/abstract/landscape/">Landscape</a><a href="/buy/abstract/man-made-objects/">Man-made Objects</a><a href="/buy/abstract/movement/">Movement</a><a href="/buy/abstract/organic/">Organic</a><a href="/buy/abstract/text/">Text</a><a href="/buy/abstract/other-abstract/">Other Abstract</a></div></div></div>
# <div class="fBox" id="fBox"><div class="boxCtnt"><div><span class="fTtl">Category</span><label class="chkBox2"><input checked="checked" name="f_c!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="1"/> Paintings &amp; Prints<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="2"/> Photography<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="5"/> Drawings &amp; Illustration<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_c!2" type="checkbox" value="6"/> Digital Art &amp; AI<div class="chkBox2_box"></div></label></div><br/><div><span class="fTtl">Original/Print</span><label class="chkBox2"><input checked="checked" name="f_o!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!2" type="checkbox" value="1"/> Original<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_o!2" type="checkbox" value="2"/> Print<div class="chkBox2_box"></div></label></div><br/>
# <div><span class="fTtl">Size</span><label class="chkBox2"><input checked="checked" name="f_sz!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="1"/> Small (up to 15")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="2"/> Medium (up to 30")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="3"/> Large (up to 50")<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_sz!2" type="checkbox" value="4"/> X-Large (more than 50")<div class="chkBox2_box"></div></label></div><br/><div><span class="fTtl">Price</span><label class="chkBox2"><input checked="checked" name="f_p!2" type="checkbox" value=""/> Any<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="0"/> $0 to $50<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="3"/> $50 to $100<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="4"/> $100 to $200<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="5"/> $200 to $500<div class="chkBox2_box"></div></label><label class="chkBox2"><input name="f_p!2" type="checkbox" value="6"/> $500+<div class="chkBox2_box"></div></label></div><br/>
# </div><div class="boxBut"><input class="button padmore" id="SubmitFilter" name="Search:" onclick="offPh(); srch(0); return rF();" type="submit" value="Apply"/>  <a class="button2sm" href="/buy/">Reset</a></div></div></div><br/><div class="i2Box subA" id="sub"><span class="fanc">Welcome, art lover!</span><br/><div class="subB"><strong>Be the first to receive coupons and sales.</strong><br/><div class="subC"><div><input autocomplete="email" maxlength="64" name="subEmail" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Your Email" size="22" type="text"/></div><div><span class="err" id="subEmailErr"></span></div><input class="button3 minpad" id="SubmitSub" onclick="offPh();go('Sub:',this,'s5w');return rF();" type="submit" value="Subscribe"/><div class="small">Your email is kept private and is not shared. You can unsubscribe at any time.</div></div><div class="subD margTop20"></div></div></div></div><div class="iC iCfnd"><div class="fnd"><span style="">Found <span>316184</span> matches</span><br/><div class="fltrPad"><div class="fltr" title="Abstract"><a class="fltrRem" href="/?"></a><span></span><div>Abstract</div></div></div></div></div><a class="iC" href="?i=293445-61" onclick="go('I:293445-61',this);return rF();"><div class="iI" style="padding-bottom:100%;"><img alt="Just Triangles - Bob Rupp" src="https://img.artpal.com/544392/61-47-32t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Just Triangles</strong><em>Bob Rupp</em></div></div></a><a class="iC" href="?i=293445-203" onclick="go('I:293445-203',this);return rF();"><div class="iI" style="padding-bottom:66.6667%;"><img alt="Stained Glass Sailboat - Bob Rupp" src="https://img.artpal.com/544392/203-13-25t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Stained Glass Sailboat</strong><em>Bob Rupp</em></div></div></a><a class="iC" href="?i=4610-15" onclick="go('I:4610-15',this);return rF();"><div class="iI" style="padding-bottom:100%;width:65.666666666666666666666666670%"><img alt="Redbud Abstract - Cara's Garden" src="https://img.artpal.com/0164/15-10-35t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Redbud Abstract</strong><em>Cara's Garden</em></div></div></a><a class="iC" href="?i=22-1403" onclick="go('I:22-1403',this);return rF();"><div class="iI" style="padding-bottom:100%;width:79.00%"><img alt="Rose Amonst the Trees - Paintings by John Lautermilch" src="https://img.artpal.com/22/1403-47-49t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Rose Amonst the Trees</strong><em>Paintings by John Lautermilch</em></div></div></a><a class="iC" href="?i=228274-96" onclick="go('I:228274-96',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Modern Circus Town Pattern - Tina Mitchell Art" src="https://img.artpal.com/472822/96-43-32t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Modern Circus Town Pattern</strong><em>Tina Mitchell Art</em></div></div></a><a class="iC" href="?i=228274-66" onclick="go('I:228274-66',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Modern Circus Town Pop Art - Tina Mitchell Art" src="https://img.artpal.com/472822/66-42-15t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>Modern Circus Town Pop Art</strong><em>Tina Mitchell Art</em></div></div></a><a class="iC" href="?i=22-1083" onclick="go('I:22-1083',this);return rF();"><div class="iI" style="padding-bottom:100%;"><img alt="End of a Small Planet - Paintings by John Lautermilch" src="https://img.artpal.com/22/1083-34-34t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><strong>End of a Small Planet</strong><em>Paintings by John Lautermilch</em></div></div></a><a class="iC" href="?i=228274-55" onclick="go('I:228274-55',this);return rF();"><div class="iI" style="padding-bottom:100%;width:80.0%"><img alt="Retro Circus Ticket Pattern - Tina Mitchell Art" src="https://img.artpal.com/472822/55-40-28t.jpg?x-l=1"/></div><div class="iT"><div class="iT2"><s ...
# <p>ArtPal's art collection gives you access to an eclectic mix of artworks &amp; artists from around the world, including figurative art, abstract art, contemporary masterpieces, impressionist art, art from the masters, realism art, abstract expressionism, modern art, and much more. The subjects depicted span the spectrum, from landscapes to animals to people to flowers to food &amp; beverage art, everyday life art, historical art, holiday art, classical art, political &amp; religious art, fantasy art, humor, abstracts, sports art, childrens art, and many more art subjects. These captivating artworks hail from galleries &amp; artists all over the globe, offering a rich tapestry of styles, subjects, and artistic types.</p>
# <p>At ArtPal, we feature a diverse selection of artists and art galleries, so you can find your unique style throughout the online store. The offerings encompass a wide range of art forms, such as fine art prints, original art, canvas prints, abstract paintings, oil paintings, giclées, limited editions, photography, drawings &amp; illustrations, digital art &amp; AI art, mixed media art, metal art, and more. Whether you're enhancing your home, or business, or professional workspace, you'll finally find the wall art that you've been searching for.</p>
# <p>In addition, it's easy to frame &amp; mat most any artwork you find on ArtPal, using the powerful online frameshop. Featuring high-quality frames &amp; mats with unparalleled custom framing workmanship and attention to detail, you're sure to be thrilled with your new art.</p>
# <p>Whether you're an experienced art collector or embarking on your first art purchase, ArtPal has an expansive art collection to ensure you find the art that's just perfect for you.</p>
# <p>Let's go art shopping!</p></div><br/><div class="wrapper footSub" id="subF"><div class="footSubB">
# <div class="subC"><strong>Get ArtPal coupons in your inbox.</strong> <div><div><input autocomplete="email" maxlength="64" name="subFEmail" onblur="Hilite(this);" onfocus="Hilite(this, true)" placeholder="Your Email" size="25" style="" type="text"/><br/><span class="err" id="subFEmailErr"></span></div> <input class="button3" id="SubmitSubF" onclick="offPh();go('Sub:F',this,'s5w');return rF();" type="submit" value="Subscribe"/></div><br/><div class="small">Your email is kept private and is not shared. You can unsubscribe at any time.</div></div><div class="subD"></div></div></div><div class="clearfix"></div>
# </div>
# <div class="footer"><div class="wrapper"><div class="footB"><img alt="ArtPal" height="29" src="https://x.artpal.com/img/artpal2.png" width="110"/></div><div class="footA small"><div class="m2 pad"><a href="#" onclick="m(this,'mShareF',1);return rF();">SHARE ARTPAL<span class="arw"></span></a><div class="m share share32" id="mShareF"><div data-img="https://x.artpal.com/img/artpal_share.png" data-title="Buy Art &amp; Sell Art! Paintings Prints Photography | ArtPal" data-url="https://www.ArtPal.com"><a class="FB" href="#" onclick="share(this);return rF();" title="Facebook"></a><a class="T" href="#" onclick="share(this);return rF();" title="Twitter"></a><a class="P" href="#" onclick="share(this);return rF();" title="Pinterest"></a><a class="E" href="#" onclick="share(this);return rF();" title="Email"></a><a class="L" href="#" onclick="share(this);return rF();" title="Copy Link"></a><a class="More" href="#" onclick="share(this);event.stopPropagation();return rF();" title="More...">More...</a></div><div class="clearfix"></div><div class="txt">Share ArtPal &amp; earn 5% referral bonuses. <a href="/refer/" target="_blank">Learn more</a></div></div></div><a href="/terms.aspx">TERMS</a><a href="/privacy.aspx">PRIVACY</a><a href="/contact.aspx" onclick="go('Contact:');return rF();">CONTACT</a><em>© 2025 ARTPAL</em></div></div></div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# window.addEventListener('load', function () { dfltTtl='Buy Abstract at ArtPal';
# upTtl("Buy Abstract at ArtPal", 0);
# $('#__EVENTTARGET').val('');$('#__EVENTARGUMENT').val('');
# $.cookie('tzo',-(new Date().getTimezoneOffset()),{expires:365, path:'/; SameSite=None; Secure'});
# initPh();
# $('#lMore').on('click',function(){loadMore=1;$(this).find('.loadSpin').spin('sm');appendItems([],1);return rF();});
# var iArry=[[342732,10,"36-45","Art Is For Everyone","Gallery 26N 80W",0,.6667],[221142,21,"42-34","Abstract River 2025 08270425","Cindy\u0026#39;s Creative Corner",0,1],[12941,50,"11-58","Yumata wife of Valu","Unispirical Muse",0,.6333],[304649,32,"42-38","on top of the world","Donnette Levine Bufton",0,.91],[539,93,"9-27","Cold Weather","Nic Squirrell",0,1],[22,550,"33-59","Abstract 1-2005","Paintings by John Lautermilch",0,.7833],[327455,38,"35-35","forest of the elders magic of wizard","Atrisane",0,.9667],[327455,32,"0-28","apple of the eye","Atrisane",0,.7967],[312387,16,"39-48","Interior paintings of Mallorca","Avanesova Elena AVA",0,1],[331939,12,"28-38","Image of the Unseen Self","Hummingbird - Where things shimmer and blur",0,.6667],[327455,7,"19-21","Geo butterfly","Atrisane",0,.78],[32227,13,"39-56","Divergent","Charlotte Blanchard",0,1],[2534,465,"25-44","Mountain High","David Zimmerman Fine Art",0,1.5152],[343457,4,"47-6","Gaelic","Monica Serban",0,1.0239],[215331,178,"31-24","In a moment","Ray",0,.64],[346550,11,"46-9","Drifting2","Margie Nottingham",0,1.0274],[22,183,"43-28","Abstract 10-2004","Paintings by John Lautermilch",0,.9867],[329030,438,"58-8","“Fragments of Light”","DRIFT POINT GALLERY",0,1.0169],[346550,10,"24-1","Drifting","Margie Nottingham",0,.98],[2534,67,"7-43","In The Mood","David Zimmerman Fine Art",0,1.3636],[2534,395,"18-57","Besert Bloom","David Zimmerman Fine Art",0,.8],[2534,404,"21-48","Leopard Skin Pill Box Hat","David Zimmerman Fine Art",0,1.25],[2534,488,"34-2","Stone age By Comparison","David Zimmerman Fine Art",0,1.4151],[346310,3,"49-22","“In the eye of becoming”","Jasmine Joyce",0,.7867],[346310,4,"58-12","“Rising”","Jasmine Joyce",0,.98],[329030,437,"32-36","“Radiance on the Horizon”","DRIFT POINT GALLERY",0,1.0169],[327674,49,"21-37","Blue roses","Amadesi Claudia",0,1.0101],[327674,69,"29-33","Totem urbano","Amadesi Claudia",0,1],[346085,112,"35-34","Elegant Abstract Leaves Wall Art","Nova Strokes",0,.6667],[12941,82,"12-55","Penxia son of Bacha","Unispirical Muse",0,.7733],[12941,84,"36-40","Subara wife of Bacha","Unispirical Muse",0,.7733],[346550,9,"54-45","Thresholds .","Margie Nottingham",0,.77],[331939,22,"10-23","Neither Zero nor One","Hummingbird - Where things shimmer and blur",0,.6667],[312387,87,"2-13","Abstract Painting Colors of Mallorca","Avanesova Elena AVA",0,1.5],[2534,293,"58-58","Madrigals","David Zimmerman Fine Art",0,1.0345],[346933,1,"11-53","Beholder","☆jjpsychcreep☆",0,.7933],[345733,5,"54-48","\u0026quot;Through the Flow\u0026quot;","Irina Beazley",0,.7233],[248349,11,"47-15","Revised Change of Heart","Diane Leon",0,.79],[2534,63,"20-17","Intensity","David Zimmerman Fine Art",0,1.3393],[346505,18,"58-41","THE FORGOTTEN SWING","XUXU",0,.7933],[312387,32,"10-49","Mallorca","Avanesova Elena AVA",0,1],[346550,8,"10-55","Yesterdays dreams","Margie Nottingham",0,1.2097],[215331,176,"10-56","Spectre","Ray",0,.6633],[22,891,"48-26","Palette Abstraction #13","Paintings by John Lautermilch",0,1.4925],[215331,174,"3-35","Ghostly","Ray",0,.6633],[215331,175,"3-39","Ocean wave.","Ray",0,1.1407],[5980,160,"30-39","Abstract Pattern in Red, Gold, Blue","JHughes Works of Art",0,1],[324961,24,"31-8","Andy Warhol Mick Jagger","Harmonia Gallery",0,1],[324961,44,"31-58","Andy Warhol Princess Diana","Harmonia Gallery",0,1],[324961,50,"43-48","Warhol Mao Tse Tung (Yellow)","Harmonia Gallery",0,1],[324961,82,"12-50","Warhol Brigitte Bardot (Green)","Harmonia Gallery",0,1],[324961,121,"56-58","Roy Lichtenstein Two Nudes","Harmonia Gallery",0,1],[324961,125,"21-59","Interior with mobile painting","Harmonia Gallery",0,1],[324961,126,"22-30","Andy Warhol Butterfly (Purple)","Harmonia Gallery",0,1],[324961,127,"22-53","Lichtenstein Nude in Kitchen","Harmonia Gallery",0,1],[324961,128,"17-18","Reflections on Crash Lichtenstein","Harmonia Gallery",0,1],[324961,129,"17-49","Lichtenstein Girl and Spray can","Harmonia Gallery",0,1],[324961,130,"18-20","Lichtenstein Reflections on Minerva", ...
# appendItems(iArry);
# initM(); initLz();
# initSChkbox(); srchFx();
# var lastItem={"gID":"346550","iID":"3"};
# var scrollID='index';scrollBotOn(scrollID,function(){$.getJSON('/getItems.ashx?',{cID:0.0100000000,gID:lastItem.gID,iID:lastItem.iID},function(data){if(data.iArry.length<100){scrollBotOff(scrollID);}lastItem=data.lastItem;appendItems(data.iArry,1);});});
#
# upTtl("Buy Abstract at ArtPal", 0);
#  });
# //]]>
# </script>
# </form>
# <div class="Popup" id="wait"><div class="PopupBgTint"></div><div class="PopupBg"><div class="waitA"><div class="waitB"></div><p><strong id="waitMsg"></strong></p></div></div></div>
# </body>
# Categories:
# Category
#  Any
#  Paintings & Prints
#  Photography
#  Drawings & Illustration
#  Digital Art & AI
#  Original/Print
#  Any
#  Original
#  Print
#  Size
#  Any
#  Small (up to 15")
#  Medium (up to 30")
#  Large (up to 50")
#  X-Large (more than 50")
#  Price
#  Any
#  $0 to $50
#  $50 to $100
#  $100 to $200
#  $200 to $500
#  $500+
#  Reset
# /buy/
# /
# /buy/
# /sellart/
# /orders.aspx
# /index.aspx?sb=1
# /
# /buy/
# /sellart/
# /orders.aspx
# /
# /buy/
# /
# /buy/abstract/
# /buy/abstract/collage/
# /buy/abstract/color/
# /buy/abstract/figurative/
# /buy/abstract/fractal/
# /buy/abstract/geometric/
# /buy/abstract/irregular-forms/
# /buy/abstract/landscape/
# /buy/abstract/man-made-objects/
# /buy/abstract/movement/
# /buy/abstract/organic/
# /buy/abstract/text/
# /buy/abstract/other-abstract/
# /buy/
# /?
# ?i=293445-61
# ?i=293445-203
# ?i=4610-15
# ?i=22-1403
# ?i=228274-96
# ?i=228274-66
# ?i=22-1083
# ?i=228274-55
# ?i=228274-54
# ?i=228274-42
# ?i=228274-41
# ?i=228274-9
# ?i=228274-1
# ?i=241829-78
# #
# #
# #
# #
# #
# #
# #
# #
# /refer/
# /terms.aspx
# /privacy.aspx
# /contact.aspx

# %%
# Extract all image URLs
images = thehtmlcode.find_all('img')
for img in images:
    print(img.get('src'))
# Out:
# https://x.artpal.com/img/artpal.png
# https://img.artpal.com/544392/61-47-32t.jpg?x-l=1
# https://img.artpal.com/544392/203-13-25t.jpg?x-l=1
# https://img.artpal.com/0164/15-10-35t.jpg?x-l=1
# https://img.artpal.com/22/1403-47-49t.jpg?x-l=1
# https://img.artpal.com/472822/96-43-32t.jpg?x-l=1
# https://img.artpal.com/472822/66-42-15t.jpg?x-l=1
# https://img.artpal.com/22/1083-34-34t.jpg?x-l=1
# https://img.artpal.com/472822/55-40-28t.jpg?x-l=1
# https://img.artpal.com/472822/54-38-50t.jpg?x-l=1
# https://img.artpal.com/472822/42-36-31t.jpg?x-l=1
# https://img.artpal.com/472822/41-35-1t.jpg?x-l=1
# https://img.artpal.com/472822/9-33-28t.jpg?x-l=1
# https://img.artpal.com/472822/1-30-42t.jpg?x-l=1
# https://img.artpal.com/928142/78-18-5t.jpg?x-l=1
# https://x.artpal.com/img/artpal2.png
